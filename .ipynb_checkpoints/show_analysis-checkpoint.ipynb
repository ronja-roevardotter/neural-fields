# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#import matplotlib as mpl
import matplotlib.ticker as ticker
from matplotlib import cm

from py.params import setParams
from py.analysis import computeFPs, checkFixPtsStability, a_jkValues
from py.analysis import tr, det, lmbd

from py.kernels import gaussian, exponential

from py.explo import collectStabilities2



# This will reload all imports as soon as the code changes
#%load_ext autoreload
#%autoreload 2

#import logging
#logger = logging.getLogger()
#logger.setLevel(logging.CRITICAL)

from py.plots.plotting import plotDiscreteMap, plotQuadrants, plotTraceDeterminant
# Out:
# 1d Model initialised.

# %%
df_show = pd.read_csv('csv/default.csv')

# %%
df_adap = pd.read_csv('csv/adap_b05_taua600.csv')

df_adap_show = df_adap[df_adap['I_e']>=-1]
df_adap_show = df_adap_show[df_adap_show['I_e']<=0.8]
df_adap_show = df_adap_show[df_adap_show['I_i']>=-1]
df_adap_show = df_adap_show[df_adap_show['I_i']<=0.2]


df_adap_show = df_adap_show[df_adap_show['p_down']==3]

# %%
import py.continuum1d as continuum1d
params=None
c1d = continuum1d.continuum1d()
# Out:
# 1d Model initialised.

# %%
a = df_adap_show #df_show[df_show['p_down']==3]
print(len(a))
ext_values = np.zeros((len(a), 2))

count = 0
for index, row in a.iterrows():
   # print(row)
    ext_values[count][0] = row['I_e']
    ext_values[count][1] = row['I_i']
    count+=1

ext_values

from py.funcs import getPSD
from py.params import setParams


df_columns=['I_e', 'I_i', 'dom_frequ', 'up_space', 'down_space']
df_new = pd.DataFrame(columns=df_columns)

count = 0
for array in ext_values:
    ee = array[0]
    ii = array[1]
    print(count, ee, ii)
    count+=1
    
    params={'I_e': ee, 'I_i': ii, 'b': 0.5, 'tau_a': 1000, 'end_t': 10*1000}
    ps = setParams(params)
    
    
    fps = computeFPs(ps)
    
    if not fps.size>0:
        fp = np.array([0.0, 0.01])
    else:
        fp=fps[0]
    stab = checkFixPtsStability(fps, ps)
    
    exc, inh = c1d.run(ps, itype='inte_fft', fp = fp)
    
    exc_test = exc.T[:,-10000]
    
 #   print(exc_test)
    
    frequs, PSD = getPSD(exc_test, ps.n)

    
    dom_frequ = frequs[np.argmax(PSD)]    
    
    if count in [0,2,4,6,8]:
        plt.figure(figsize=(3,3))
        
        plt.imshow(exc.T[:,-500:], vmin=0, vmax=1, aspect='auto')
        plt.show()
        
        plt.figure(figsize=(3,3))
        plt.plot(frequs, PSD)
        plt.show()
        print(dom_frequ)
    
    
    e = exc_test
    maxi = max(e)
    up_nodes = sum(x>=0.4*maxi for x in e)
    down_nodes = sum(x < 0.4*maxi for x in e)
    up_nodes, down_nodes
    nodes_per_down = down_nodes/dom_frequ
    nodes_per_up = up_nodes/dom_frequ
    space_per_down = ps.dx * nodes_per_down
    space_per_up = ps.dx * nodes_per_up

    values = [[ee, ii, dom_frequ, space_per_up, space_per_down]]
    df_temp = pd.DataFrame(values, columns=df_columns)
    df_new = pd.concat([df_new, df_temp])
    
    
    
df_new
# Out:
# 45
# 0 -0.5333333333333332 -0.9777777777777776
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:29: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_i*(x-params.mu_i)))
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 1 -0.5333333333333332 -0.9333333333333332
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 6.0
# 2 -0.5333333333333332 -0.8888888888888888
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 3 -0.4888888888888889 -0.9777777777777776
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /var/folders/8l/w8cdnkkj38bg2pscx__1vxth0000gn/T/ipykernel_3139/2180295072.py:67: RuntimeWarning: invalid value encountered in true_divide
#   nodes_per_down = down_nodes/dom_frequ
# /var/folders/8l/w8cdnkkj38bg2pscx__1vxth0000gn/T/ipykernel_3139/2180295072.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   nodes_per_up = up_nodes/dom_frequ
# 0.0
# 4 -0.4888888888888889 -0.9333333333333332
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 5 -0.4888888888888889 -0.8888888888888888
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 6.0
# 6 -0.4888888888888889 -0.8444444444444443
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 7 -0.4888888888888889 -0.8
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 5.0
# 8 -0.4444444444444444 -0.9777777777777776
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /var/folders/8l/w8cdnkkj38bg2pscx__1vxth0000gn/T/ipykernel_3139/2180295072.py:67: RuntimeWarning: invalid value encountered in true_divide
#   nodes_per_down = down_nodes/dom_frequ
# /var/folders/8l/w8cdnkkj38bg2pscx__1vxth0000gn/T/ipykernel_3139/2180295072.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   nodes_per_up = up_nodes/dom_frequ
# 9 -0.4444444444444444 -0.9333333333333332
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /var/folders/8l/w8cdnkkj38bg2pscx__1vxth0000gn/T/ipykernel_3139/2180295072.py:67: RuntimeWarning: invalid value encountered in true_divide
#   nodes_per_down = down_nodes/dom_frequ
# /var/folders/8l/w8cdnkkj38bg2pscx__1vxth0000gn/T/ipykernel_3139/2180295072.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   nodes_per_up = up_nodes/dom_frequ
# 10 -0.4444444444444444 -0.8888888888888888
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 11 -0.4444444444444444 -0.8444444444444443
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 12 -0.4444444444444444 -0.8
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 13 -0.4444444444444444 -0.7555555555555555
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 14 -0.3999999999999999 -0.8888888888888888
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /var/folders/8l/w8cdnkkj38bg2pscx__1vxth0000gn/T/ipykernel_3139/2180295072.py:67: RuntimeWarning: invalid value encountered in true_divide
#   nodes_per_down = down_nodes/dom_frequ
# /var/folders/8l/w8cdnkkj38bg2pscx__1vxth0000gn/T/ipykernel_3139/2180295072.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   nodes_per_up = up_nodes/dom_frequ
# 15 -0.3999999999999999 -0.8444444444444443
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 16 -0.3999999999999999 -0.8
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 17 -0.3999999999999999 -0.7555555555555555
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 18 -0.3999999999999999 -0.711111111111111
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 19 -0.3555555555555554 -0.8
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 20 -0.3555555555555554 -0.7555555555555555
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 21 -0.3555555555555554 -0.711111111111111
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 22 -0.3555555555555554 -0.6666666666666665
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 23 -0.3111111111111111 -0.7555555555555555
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 24 -0.3111111111111111 -0.711111111111111
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 25 -0.3111111111111111 -0.6666666666666665
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 26 -0.3111111111111111 -0.6222222222222222
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 27 -0.2666666666666666 -0.711111111111111
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 28 -0.2666666666666666 -0.6666666666666665
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 29 -0.2666666666666666 -0.6222222222222222
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 30 -0.2666666666666666 -0.5777777777777777
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 31 -0.2222222222222221 -0.6666666666666665
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 32 -0.2222222222222221 -0.6222222222222222
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 33 -0.2222222222222221 -0.5777777777777777
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 34 -0.2222222222222221 -0.5333333333333332
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 35 -0.1777777777777778 -0.6222222222222222
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 36 -0.1777777777777778 -0.5777777777777777
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 37 -0.1777777777777778 -0.5333333333333332
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 38 -0.1333333333333333 -0.5777777777777777
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 39 -0.1333333333333333 -0.5333333333333332
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 40 -0.1333333333333333 -0.4888888888888889
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 41 -0.0888888888888888 -0.4888888888888889
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 42 -0.0888888888888888 -0.4444444444444444
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 43 -0.0444444444444442 -0.3999999999999999
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 44 0.3555555555555556 -0.2222222222222221
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 8192 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /var/folders/8l/w8cdnkkj38bg2pscx__1vxth0000gn/T/ipykernel_3139/2180295072.py:67: RuntimeWarning: invalid value encountered in true_divide
#   nodes_per_down = down_nodes/dom_frequ
# /var/folders/8l/w8cdnkkj38bg2pscx__1vxth0000gn/T/ipykernel_3139/2180295072.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   nodes_per_up = up_nodes/dom_frequ
#         I_e       I_i dom_frequ  up_space down_space
# 0 -0.533333 -0.977778       6.0  2.734375   5.598958
# 0 -0.533333 -0.933333       6.0  2.604167   5.729167
# 0 -0.533333 -0.888889       5.0    2.8125     7.1875
# 0 -0.488889 -0.977778       0.0       inf        NaN
# 0 -0.488889 -0.933333       6.0  2.864583    5.46875
# 0 -0.488889 -0.888889       6.0  2.734375   5.598958
# 0 -0.488889 -0.844444       6.0  2.604167   5.729167
# 0 -0.488889      -0.8       5.0    2.8125     7.1875
# 0 -0.444444 -0.977778       0.0       inf        NaN
# 0 -0.444444 -0.933333       0.0       inf        NaN
# 0 -0.444444 -0.888889       6.0  2.864583    5.46875
# 0 -0.444444 -0.844444       6.0  2.864583    5.46875
# 0 -0.444444      -0.8       5.0  3.203125   6.796875
# 0 -0.444444 -0.755556       6.0  2.604167   5.729167
# 0      -0.4 -0.888889       0.0       inf        NaN
# 0      -0.4 -0.844444       6.0  2.994792   5.338542
# 0      -0.4      -0.8       6.0  2.994792   5.338542
# 0      -0.4 -0.755556       6.0  2.864583    5.46875
# 0      -0.4 -0.711111       6.0  2.734375   5.598958
# 0 -0.355556      -0.8       6.0  3.255208   5.078125
# 0 -0.355556 -0.755556       6.0  2.994792   5.338542
# 0 -0.355556 -0.711111       5.0    3.4375     6.5625
# 0 -0.355556 -0.666667       6.0  2.864583    5.46875
# 0 -0.311111 -0.755556       6.0  3.255208   5.078125
# 0 -0.311111 -0.711111       6.0     3.125   5.208333
# 0 -0.311111 -0.666667       5.0   3.59375    6.40625
# 0 -0.311111 -0.622222       6.0  2.994792   5.338542
# 0 -0.266667 -0.711111       6.0  3.385417   4.947917
# 0 -0.266667 -0.666667       6.0  3.385417   4.947917
# 0 -0.266667 -0.622222       6.0     3.125   5.208333
# 0 -0.266667 -0.577778       6.0     3.125   5.208333
# 0 -0.222222 -0.666667       6.0  3.515625   4.817708
# 0 -0.222222 -0.622222       6.0  3.385417   4.947917
# 0 -0.222222 -0.577778       6.0  3.255208   5.078125
# 0 -0.222222 -0.533333       6.0  3.255208   5.078125
# 0 -0.177778 -0.622222       6.0  3.515625   4.817708
# 0 -0.177778 -0.577778       6.0  3.515625   4.817708
# 0 -0.177778 -0.533333       6.0  3.385417   4.947917
# 0 -0.133333 -0.577778       6.0  3.776042   4.557292
# 0 -0.133333 -0.533333       6.0  3.645833     4.6875
# 0 -0.133333 -0.488889       6.0  3.515625   4.817708
# 0 -0.088889 -0.488889       6.0  3.776042   4.557292
# 0 -0.088889 -0.444444       6.0  3.515625   4.817708
# 0 -0.044444      -0.4       6.0  3.776042   4.557292
# 0  0.355556 -0.222222       0.0       inf        NaN

# %%
df_new.to_csv('adaps_space_frequs.csv')

# %%
df_new

# %%
df_new.plot.hist(column=['up_space', 'down_space'], density = True, alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
e = exc[-1000]
up_nodes = sum(x>=0.2 for x in e)
down_nodes = sum(x < 0.2 for x in e)
up_nodes, down_nodes
nodes_per_down = down_nodes/dom_frequ
nodes_per_up = up_nodes/dom_frequ
space_per_down = ps.dx * nodes_per_down
space_per_up = ps.dx * nodes_per_up
space_per_down, space_per_up
(space_per_down+space_per_down)*dom_frequ
# Out:
# 50.0

# %%
#logging.disabled
params={'I_e': 0.0, 'I_i': 0, 'b': 0.5, 'tau_a': 600}
df = collectStabilities2(params, vary_params={'I_e': np.linspace(-1,1,81), 'I_i': np.linspace(-2,2,81)})

# %%
df.to_csv('adap__b05_taua600.csv')

# %%
#logging.disabled
params={'I_e': 0.0, 'I_i': 0, 'b': 0}
df = collectStabilities2(params, vary_params={'I_e': np.linspace(-2,2,81), 'I_i': np.linspace(-2,2,81)})

# %%
df.to_csv('default.csv')

# %%
params={'I_e': 0.0, 'I_i': 0, 'b': 0}
df = collectStabilities2(params, vary_params={'I_e': np.linspace(-1,1,31), 'I_i': np.linspace(-1,1,31)})

df.to_csv('default_lowres.csv')

# %%
params={'I_e': 0.0, 'I_i': 0, 'b': 0, 'sigma_i': 0.6, 'tau_i': 0.6}
df = collectStabilities2(params, vary_params={'I_e': np.linspace(-1,1,31), 'I_i': np.linspace(-1,1,31)})

# %%
df.to_csv('bif_sigmai_06_taui_06.csv')

# %%
params={'I_e': 0.0, 'I_i': 0, 'b': 0, 'sigma_i': 0.6, 'tau_i': 1.5}
df = collectStabilities2(params, vary_params={'I_e': np.linspace(-1,1,31), 'I_i': np.linspace(-1,1,31)})

# %%
df.to_csv('bif_sigmai_06_taui_15.csv')

# %%
params={'I_e': 0.0, 'I_i': 0, 'b': 0, 'sigma_i': 0.6, 'tau_i': 2.4}
df = collectStabilities2(params, vary_params={'I_e': np.linspace(-1,1,31), 'I_i': np.linspace(-1,1,31)})

# %%
df.to_csv('bif_sigmai_06_taui_24.csv')

# %%
params={'I_e': 0.0, 'I_i': 0, 'b': 0, 'sigma_i': 0.6, 'tau_i': 3.0}
df = collectStabilities2(params, vary_params={'I_e': np.linspace(-1,1,31), 'I_i': np.linspace(-1,1,31)})

# %%
df.to_csv('bif_sigmai_06_taui_30.csv')

# %%
params={}
params={'I_e': 0, 'I_i': 0, 'w_ei': 3.2}
df = collectStabilities2(params, vary_params={'I_e': np.linspace(-1,1,31), 'I_i': np.linspace(-1,1,31)})

# %%
df.to_csv('wei_32.csv')

# %%
params={}
params={'I_e': 0, 'I_i': 0, 'w_ie': 3.9}
df = collectStabilities2(params, vary_params={'I_e': np.linspace(-1,1,31), 'I_i': np.linspace(-1,1,31)})

# %%
df.to_csv('wie_39.csv')

# %%
params={'I_e': 0, 'I_i': 0, 'end_t': 1000, 'length': 50, 'beta_e': 5, 'beta_i': 5,
       'w_ee': 3.1, 'w_ei': 2.6, 'w_ie': 3.2, 'w_ii': 0.8}

from py.analysis import determinant_Turing_Hopf

l=101

ee = -0.55
ii = np.linspace(-0.76,-0.77,11)
traces = np.zeros((len(ii), l))
determinants = np.zeros((len(ii), l))
params['I_e'] = ee
for idx, val in enumerate(ii):
    params['I_i']=val
    ps = setParams(params)
    fps = computeFPs(ps)
    stab = checkFixPtsStability(fps, ps)
    
    print('For I_i=%.4f, we have fixed points: %s, and stability: %s' %(val, str(fps), str(stab)))
    
    a_ee, a_ei, a_ie, a_ii = a_jkValues(fps[0], ps)
    
    k = np.linspace(-2,2,l)
    determinant = det(k, a_ee, a_ei, a_ie, a_ii, ps)
    zero_det, zero_deriv_det, pos_trace = determinant_Turing_Hopf(k, a_ee, a_ii, a_ei, a_ie, ps)
    print('det = %s, deriv_det = %s' %(str(zero_det), str(zero_deriv_det)))
    trace = tr(k, a_ee, a_ii, ps)
    traces[idx] = trace
    determinants[idx] = determinant
