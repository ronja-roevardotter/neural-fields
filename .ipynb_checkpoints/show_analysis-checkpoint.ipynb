# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#import matplotlib as mpl
import matplotlib.ticker as ticker
from matplotlib import cm

from py.params import setParams
from py.analysis import computeFPs, checkFixPtsStability, a_jkValues
from py.analysis import tr, det, lmbd

from py.kernels import gaussian, exponential

from py.explo import collectStabilities2



# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

from py.plots.plotting import plot2DiscreteMaps, plotQuadrants, plotTraceDeterminant

# %%
df_show = pd.read_csv('higher_beta.csv')

# %%
plot2DiscreteMaps(df_show)
# Out:
# /Users/ronja/Documents/GitHub/neural-fields/py/plots/plotting.py:26: UserWarning: No contour levels were found within the data range.
#   ax2.imshow(p_turings, origin='lower', vmin=1, vmax=4, aspect='auto', cmap=p_colors)
# /Users/ronja/Documents/GitHub/neural-fields/py/plots/plotting.py:31: UserWarning: No contour levels were found within the data range.
#
# /Users/ronja/Documents/GitHub/neural-fields/py/plots/plotting.py:57: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# /Users/ronja/Documents/GitHub/neural-fields/py/plots/plotting.py:59: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_ylabel(r'$%s$' %yaxis, fontsize=20, labelpad=10, rotation=0)

# %%
params={'I_e': 0, 'I_i': 0, 'end_t': 1000, 'length': 50, 'beta_e': 4, 'beta_i': 4}
df = collectStabilities2(params, vary_params={'I_e': np.linspace(-3,3,51), 'I_i': np.linspace(-5,2,51)})
# Out:
# <class 'str'> <class 'numpy.ndarray'>
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -5.000000, i=0, j=0 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -4.860000, i=0, j=1 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -4.720000, i=0, j=2 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -4.580000, i=0, j=3 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -4.440000, i=0, j=4 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -4.300000, i=0, j=5 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -4.160000, i=0, j=6 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -4.020000, i=0, j=7 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -3.880000, i=0, j=8 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -3.740000, i=0, j=9 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -3.600000, i=0, j=10 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -3.460000, i=0, j=11 with random pattern 1
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:25: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_e*(x-params.mu_e)))
# 1d Model initialised.
# We are in round I_e = -3.000000, I_i = -3.320000, i=0, j=12 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -3.180000, i=0, j=13 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -3.040000, i=0, j=14 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -2.900000, i=0, j=15 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -2.760000, i=0, j=16 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -2.620000, i=0, j=17 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -2.480000, i=0, j=18 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -2.340000, i=0, j=19 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -2.200000, i=0, j=20 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -2.060000, i=0, j=21 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -1.920000, i=0, j=22 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -1.780000, i=0, j=23 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -1.640000, i=0, j=24 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -1.500000, i=0, j=25 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -1.360000, i=0, j=26 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -1.220000, i=0, j=27 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -1.080000, i=0, j=28 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -0.940000, i=0, j=29 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -0.800000, i=0, j=30 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -0.660000, i=0, j=31 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -0.520000, i=0, j=32 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -0.380000, i=0, j=33 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -0.240000, i=0, j=34 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -0.100000, i=0, j=35 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = 0.040000, i=0, j=36 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = 0.180000, i=0, j=37 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = 0.320000, i=0, j=38 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = 0.460000, i=0, j=39 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = 0.600000, i=0, j=40 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = 0.740000, i=0, j=41 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = 0.880000, i=0, j=42 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = 1.020000, i=0, j=43 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = 1.160000, i=0, j=44 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = 1.300000, i=0, j=45 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = 1.440000, i=0, j=46 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = 1.580000, i=0, j=47 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = 1.720000, i=0, j=48 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = 1.860000, i=0, j=49 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = 2.000000, i=0, j=50 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -5.000000, i=1, j=0 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -4.860000, i=1, j=1 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -4.720000, i=1, j=2 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -4.580000, i=1, j=3 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -4.440000, i=1, j=4 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -4.300000, i=1, j=5 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -4.160000, i=1, j=6 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:25: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_e*(x-params.mu_e)))
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:29: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_i*(x-params.mu_i)))
# We are in round I_e = -2.880000, I_i = -4.020000, i=1, j=7 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -3.880000, i=1, j=8 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -3.740000, i=1, j=9 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:25: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_e*(x-params.mu_e)))
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:29: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_i*(x-params.mu_i)))
# We are in round I_e = -2.880000, I_i = -3.600000, i=1, j=10 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -3.460000, i=1, j=11 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:25: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_e*(x-params.mu_e)))
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:29: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_i*(x-params.mu_i)))
# We are in round I_e = -2.880000, I_i = -3.320000, i=1, j=12 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -3.180000, i=1, j=13 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -3.040000, i=1, j=14 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:25: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_e*(x-params.mu_e)))
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:29: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_i*(x-params.mu_i)))
# We are in round I_e = -2.880000, I_i = -2.900000, i=1, j=15 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -2.760000, i=1, j=16 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -2.620000, i=1, j=17 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -2.480000, i=1, j=18 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -2.340000, i=1, j=19 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -2.200000, i=1, j=20 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -2.060000, i=1, j=21 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -1.920000, i=1, j=22 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -1.780000, i=1, j=23 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -1.640000, i=1, j=24 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -1.500000, i=1, j=25 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -1.360000, i=1, j=26 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -1.220000, i=1, j=27 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -1.080000, i=1, j=28 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -0.940000, i=1, j=29 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -0.800000, i=1, j=30 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -0.660000, i=1, j=31 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -0.520000, i=1, j=32 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -0.380000, i=1, j=33 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -0.240000, i=1, j=34 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = -0.100000, i=1, j=35 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = 0.040000, i=1, j=36 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = 0.180000, i=1, j=37 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = 0.320000, i=1, j=38 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = 0.460000, i=1, j=39 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = 0.600000, i=1, j=40 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = 0.740000, i=1, j=41 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = 0.880000, i=1, j=42 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = 1.020000, i=1, j=43 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = 1.160000, i=1, j=44 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = 1.300000, i=1, j=45 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = 1.440000, i=1, j=46 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = 1.580000, i=1, j=47 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = 1.720000, i=1, j=48 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = 1.860000, i=1, j=49 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.880000, I_i = 2.000000, i=1, j=50 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -5.000000, i=2, j=0 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -4.860000, i=2, j=1 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -4.720000, i=2, j=2 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -4.580000, i=2, j=3 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -4.440000, i=2, j=4 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -4.300000, i=2, j=5 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -4.160000, i=2, j=6 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -4.020000, i=2, j=7 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -3.880000, i=2, j=8 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -3.740000, i=2, j=9 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -3.600000, i=2, j=10 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -3.460000, i=2, j=11 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -3.320000, i=2, j=12 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -3.180000, i=2, j=13 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -3.040000, i=2, j=14 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -2.900000, i=2, j=15 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -2.760000, i=2, j=16 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -2.620000, i=2, j=17 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:25: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_e*(x-params.mu_e)))
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:29: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_i*(x-params.mu_i)))
# We are in round I_e = -2.760000, I_i = -2.480000, i=2, j=18 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:25: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_e*(x-params.mu_e)))
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:29: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_i*(x-params.mu_i)))
# We are in round I_e = -2.760000, I_i = -2.340000, i=2, j=19 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:25: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_e*(x-params.mu_e)))
# /Users/ronja/Documents/GitHub/neural-fields/py/analysis.py:29: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-params.beta_i*(x-params.mu_i)))
# We are in round I_e = -2.760000, I_i = -2.200000, i=2, j=20 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -2.060000, i=2, j=21 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -1.920000, i=2, j=22 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -1.780000, i=2, j=23 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -1.640000, i=2, j=24 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -1.500000, i=2, j=25 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -1.360000, i=2, j=26 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -1.220000, i=2, j=27 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -1.080000, i=2, j=28 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -0.940000, i=2, j=29 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -0.800000, i=2, j=30 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -2.760000, I_i = -0.660000, i=2, j=31 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# ...
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -4.160000, i=50, j=6 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -4.020000, i=50, j=7 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -3.880000, i=50, j=8 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -3.740000, i=50, j=9 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -3.600000, i=50, j=10 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -3.460000, i=50, j=11 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -3.320000, i=50, j=12 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -3.180000, i=50, j=13 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -3.040000, i=50, j=14 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -2.900000, i=50, j=15 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -2.760000, i=50, j=16 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -2.620000, i=50, j=17 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -2.480000, i=50, j=18 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -2.340000, i=50, j=19 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -2.200000, i=50, j=20 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -2.060000, i=50, j=21 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -1.920000, i=50, j=22 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -1.780000, i=50, j=23 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -1.640000, i=50, j=24 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -1.500000, i=50, j=25 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -1.360000, i=50, j=26 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -1.220000, i=50, j=27 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -1.080000, i=50, j=28 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -0.940000, i=50, j=29 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -0.800000, i=50, j=30 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -0.660000, i=50, j=31 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -0.520000, i=50, j=32 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -0.380000, i=50, j=33 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -0.240000, i=50, j=34 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = -0.100000, i=50, j=35 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = 0.040000, i=50, j=36 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = 0.180000, i=50, j=37 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = 0.320000, i=50, j=38 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 1d Model initialised.
# We are in round I_e = 3.000000, I_i = 0.460000, i=50, j=39 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = 0.600000, i=50, j=40 with random pattern 1
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 1d Model initialised.
# We are in round I_e = 3.000000, I_i = 0.740000, i=50, j=41 with random pattern 1
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# 1d Model initialised.
# We are in round I_e = 3.000000, I_i = 0.880000, i=50, j=42 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = 1.020000, i=50, j=43 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = 1.160000, i=50, j=44 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = 1.300000, i=50, j=45 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = 1.440000, i=50, j=46 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = 1.580000, i=50, j=47 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = 1.720000, i=50, j=48 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = 3.000000, I_i = 1.860000, i=50, j=49 with random pattern 1
# 1d Model initialised.
# We are in round I_e = 3.000000, I_i = 2.000000, i=50, j=50 with random pattern 1
# df:      I_e   I_i stability turing turing_hopf p_random p_turing
# 0  -3.0  -5.0         1      0           0        1        0
# 0  -3.0 -4.86         1      0           0        1        0
# 0  -3.0 -4.72         1      0           0        1        0
# 0  -3.0 -4.58         1      0           0        1        0
# 0  -3.0 -4.44         1      0           0        1        0
# ..  ...   ...       ...    ...         ...      ...      ...
# 0   3.0  1.44         1      0           0        1        0
# 0   3.0  1.58         1      0           0        1        0
# 0   3.0  1.72         1      0           0        1        0
# 0   3.0  1.86         1      0           0        1        0
# 0   3.0   2.0         1      0           0        1        0
#
# [2601 rows x 7 columns]
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '

# %%
df.to_csv('higher_beta.csv')

# %%
l=101

ee = -2.4
ii = np.linspace(-2.84,-2.82,6)
traces = np.zeros((len(ii), l))
determinants = np.zeros((len(ii), l))
for idx, val in enumerate(ii):
    params['I_i']=val
    ps = setParams(params)
    fps = computeFPs(ps)
    stab = checkFixPtsStability(fps, ps)
    
    print('For I_i=%.4f, we have fixed points: %s, and stability: %s' %(val, str(fps), str(stab)))
    
    a_ee, a_ei, a_ie, a_ii = a_jkValues(fps[0], ps)
    
    k = np.linspace(-2,2,l)
    determinant = det(k, a_ee, a_ei, a_ie, a_ii, ps)
    trace = tr(k, a_ee, a_ii, ps)
    traces[idx] = trace
    determinants[idx] = determinant

# %%
plotQuadrants(traces, determinants)
plotTraceDeterminant(traces, determinants, k)

# %%
df_show[df_show['p_random']==4]
