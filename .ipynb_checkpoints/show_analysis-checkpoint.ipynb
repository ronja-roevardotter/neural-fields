# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#import matplotlib as mpl
import matplotlib.ticker as ticker
from matplotlib import cm

from py.params import setParams
from py.analysis import computeFPs, checkFixPtsStability, a_jkValues
from py.analysis import tr, det, lmbd

from py.kernels import gaussian, exponential

from py.explo import collectStabilities2



# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

from py.plots.plotting import plot2DiscreteMaps, plotQuadrants, plotTraceDeterminant

# %%
df_show = pd.read_csv('default.csv')

# %%
plot2DiscreteMaps(df_show)

# %%
df2 = pd.read_csv('sigmai_06_taui_15.csv')

# %%
plot2DiscreteMaps(df2)
# Out:
# /Users/ronja/Documents/GitHub/neural-fields/py/plots/plotting.py:23: UserWarning: No contour levels were found within the data range.
#   ax1.contour(turings, origin='lower', vmin=0, vmax=1, levels=0, colors='black', linewidths=3, linestyles='dashed')
# /Users/ronja/Documents/GitHub/neural-fields/py/plots/plotting.py:28: UserWarning: No contour levels were found within the data range.
#   ax2.contour(turings, origin='lower', vmin=0, vmax=1, levels=0, colors='black', linewidths=3, linestyles='dashed')
# /Users/ronja/Documents/GitHub/neural-fields/py/plots/plotting.py:54: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels=xlabels, fontsize=20)
# /Users/ronja/Documents/GitHub/neural-fields/py/plots/plotting.py:56: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(labels=ylabels, fontsize=20)

# %%
params={'I_e': 0, 'I_i': 0, 'end_t': 1200, 'length': 50}
df = collectStabilities2(params, vary_params={'I_e': np.linspace(-3,3,21), 'I_i': np.linspace(-5,3,21)})
# Out:
# <class 'str'> <class 'numpy.ndarray'>
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -5.000000, i=0, j=0 with random pattern 2
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -4.600000, i=0, j=1 with random pattern 2
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -4.200000, i=0, j=2 with random pattern 2
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -3.800000, i=0, j=3 with random pattern 3
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -3.400000, i=0, j=4 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -3.000000, i=0, j=5 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -2.600000, i=0, j=6 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -2.200000, i=0, j=7 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -1.800000, i=0, j=8 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -1.400000, i=0, j=9 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -1.000000, i=0, j=10 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -0.600000, i=0, j=11 with random pattern 1
# 1d Model initialised.
# /Users/ronja/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/spectral.py:1964: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   warnings.warn('nperseg = {0:d} is greater than input length '
# We are in round I_e = -3.000000, I_i = -0.200000, i=0, j=12 with random pattern 1
# 1d Model initialised.

# %%
df.to_csv('default.csv')

# %%
l=101

ee = -2.4
ii = np.linspace(-2.84,-2.82,6)
traces = np.zeros((len(ii), l))
determinants = np.zeros((len(ii), l))
for idx, val in enumerate(ii):
    params['I_i']=val
    ps = setParams(params)
    fps = computeFPs(ps)
    stab = checkFixPtsStability(fps, ps)
    
    print('For I_i=%.4f, we have fixed points: %s, and stability: %s' %(val, str(fps), str(stab)))
    
    a_ee, a_ei, a_ie, a_ii = a_jkValues(fps[0], ps)
    
    k = np.linspace(-2,2,l)
    determinant = det(k, a_ee, a_ei, a_ie, a_ii, ps)
    trace = tr(k, a_ee, a_ii, ps)
    traces[idx] = trace
    determinants[idx] = determinant
# Out:
# For I_i=-2.8400, we have fixed points: [[0.9990989  0.99788279]], and stability: [1]
# For I_i=-2.8360, we have fixed points: [[0.9990988  0.99789117]], and stability: [1]
# For I_i=-2.8320, we have fixed points: [[0.99909871 0.99789952]], and stability: [1]
# For I_i=-2.8280, we have fixed points: [[0.99909862 0.99790783]], and stability: [1]
# For I_i=-2.8240, we have fixed points: [[0.99909853 0.99791611]], and stability: [1]
# For I_i=-2.8200, we have fixed points: [[0.99909844 0.99792436]], and stability: [1]

# %%
plotQuadrants(traces, determinants)
plotTraceDeterminant(traces, determinants, k)

# %%
df_show[df_show['p_random']==4]
# Out:
#       Unnamed: 0   I_e   I_i  stability  turing  turing_hopf  p_random  \
# 105            0 -2.76 -4.52          0       0            0         4
# 312            0 -2.28 -4.04          1       1            0         4
# 467            0 -1.92 -3.72          1       1            0         4
# 665            0 -1.44 -4.68          0       0            0         4
# 725            0 -1.32 -3.24          1       1            0         4
# 828            0 -1.08 -3.08          1       1            0         4
# 924            0 -0.84 -4.04          0       0            0         4
# 976            0 -0.72 -3.88          0       0            0         4
# 1028           0 -0.60 -3.72          0       0            0         4
# 1080           0 -0.48 -3.56          0       0            0         4
# 1132           0 -0.36 -3.40          1       0            0         4
# 1137           0 -0.36 -2.60          1       1            0         4
# 1184           0 -0.24 -3.24          1       0            0         4
# 1240           0 -0.12 -2.44          2       1            0         4
# 1343           0  0.12 -2.28          2       1            0         4
#
#       p_turing
# 105          0
# 312          3
# 467          3
# 665          0
# 725          3
# 828          3
# 924          0
# 976          0
# 1028         0
# 1080         0
# 1132         0
# 1137         3
# 1184         0
# 1240         3
# 1343         3
