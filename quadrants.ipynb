# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib import cm

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

from py.plots.plotting import plot2DiscreteMaps, plotQuadrants, plotTraceDeterminant

# %%
trace = np.array([np.linspace(-0.2,-0.1,21)])

determinant = np.array([np.concatenate((np.linspace(0.2,0,11), np.linspace(-0.02,0.2,10)), axis=None)])
determinant
# Out:
# array([[ 0.2       ,  0.18      ,  0.16      ,  0.14      ,  0.12      ,
#          0.1       ,  0.08      ,  0.06      ,  0.04      ,  0.02      ,
#          0.        , -0.02      ,  0.00444444,  0.02888889,  0.05333333,
#          0.07777778,  0.10222222,  0.12666667,  0.15111111,  0.17555556,
#          0.2       ]])

# %%
plotQuadrants(trace, determinant, axis_max=0.2)

# %%
plotQuadrants(-determinant, -trace, axis_max=0.2)

# %%
correct_tr = np.array([np.linspace(-0.2, -0.02,21)])
correct_det = np.array([np.linspace(0.02, 0.2,21)])

# %%
plotQuadrants(correct_tr, correct_det, axis_max=0.2)
